# %%
import diaux
import numpy as np
import pandas as pd

import iqplot

import bokeh.io
import bokeh.plotting
import colorcet
bokeh.io.output_notebook()

import scipy.optimize

import matplotlib.pyplot as plt

from io import StringIO

colors=diaux.viz.matplotlib_style();
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a93d1b71-cecd-4687-bfdd-29a50b013348">Loading BokehJS ...</span>
#     </div>

# %%
well_metadata = {
    "A1": "1:0_1",
    "B1": "1:0_1",
    "C1": "1:0_1",
    "D1": "1:0_1",
    "E1": "1:0_2",
    "F1": "1:0_2",
    "G1": "1:0_2",
    "H1": "1:0_2",
    "A2": "1:1_1",
    "B2": "1:1_1",
    "C2": "1:1_1",
    "D2": "1:1_1",
    "E2": "1:1_2",
    "F2": "1:1_2",
    "G2": "1:1_2",
    "H2": "1:1_2",
    "A3": "1:1.78_1",
    "B3": "1:1.78_1",
    "C3": "1:1.78_1",
    "D3": "1:1.78_1",
    "E3": "1:1.78_2",
    "F3": "1:1.78_2",
    "G3": "1:1.78_2",
    "H3": "1:1.78_2",
    "A4": "1:3.16_1",
    "B4": "1:3.16_1",
    "C4": "1:3.16_1",
    "D4": "1:3.16_1",
    "E4": "1:3.16_2",
    "F4": "1:3.16_2",
    "G4": "1:3.16_2",
    "H4": "1:3.16_2",
    "A5": "1:5.62_1",
    "B5": "1:5.62_1",
    "C5": "1:5.62_1",
    "D5": "1:5.62_1",
    "E5": "1:5.62_2",
    "F5": "1:5.62_2",
    "G5": "1:5.62_2",
    "H5": "1:5.62_2",
    "A6": "1:10.0_1",
    "B6": "1:10.0_1",
    "C6": "1:10.0_1",
    "D6": "1:10.0_1",
    "E6": "1:10.0_2",
    "F6": "1:10.0_2",
    "G6": "1:10.0_2",
    "H6": "1:10.0_2",
    "A7": "1:17.78_1",
    "B7": "1:17.78_1",
    "C7": "1:17.78_1",
    "D7": "1:17.78_1",
    "E7": "1:17.78_2",
    "F7": "1:17.78_2",
    "G7": "1:17.78_2",
    "H7": "1:17.78_2",
    "A8": "1:31.62_1",
    "B8": "1:31.62_1",
    "C8": "1:31.62_1",
    "D8": "1:31.62_1",
    "E8": "1:31.62_2",
    "F8": "1:31.62_2",
    "G8": "1:31.62_2",
    "H8": "1:31.62_2",
    "A9": "1:56.23_1",
    "B9": "1:56.23_1",
    "C9": "1:56.23_1",
    "D9": "1:56.23_1",
    "E9": "1:56.23_2",
    "F9": "1:56.23_2",
    "G9": "1:56.23_2",
    "H9": "1:56.23_2",
    "A10": "1:100.0_1",
    "B10": "1:100.0_1",
    "C10": "1:100.0_1",
    "D10": "1:100.0_1",
    "E10": "1:100.0_2",
    "F10": "1:100.0_2",
    "G10": "1:100.0_2",
    "H10": "1:100.0_2",
    "A11": "0:1_1",
    "B11": "0:1_1",
    "C11": "0:1_1",
    "D11": "0:1_1",
    "E11": "0:1_2",
    "F11": "0:1_2",
    "G11": "0:1_2",
    "H11": "0:1_2",
    #"A12": "blank",
    "B12": "blank",
    "C12": "blank",
    "D12": "blank",
    "E12": "blank",
    "F12": "blank",
    #"G12": "blank",
    #"H12": "blank",
}

# %%
def invert_dict(input_dict):
    """Invert a dictionary ignore None values."""
    # Create an empty dictionary to store the inverted mapping
    output_dict = {}

    # Iterate over items in the input dictionary
    for key, value in input_dict.items():
        if value is not None:
            if value in output_dict:
                output_dict[value].append(key)
            else:
                output_dict[value] = [key]

    return output_dict

# %%
conditions = invert_dict(well_metadata)

conditions
# Out:
# {'1:0_1': ['A1', 'B1', 'C1', 'D1'],
#  '1:0_2': ['E1', 'F1', 'G1', 'H1'],
#  '1:1_1': ['A2', 'B2', 'C2', 'D2'],
#  '1:1_2': ['E2', 'F2', 'G2', 'H2'],
#  '1:1.78_1': ['A3', 'B3', 'C3', 'D3'],
#  '1:1.78_2': ['E3', 'F3', 'G3', 'H3'],
#  '1:3.16_1': ['A4', 'B4', 'C4', 'D4'],
#  '1:3.16_2': ['E4', 'F4', 'G4', 'H4'],
#  '1:5.62_1': ['A5', 'B5', 'C5', 'D5'],
#  '1:5.62_2': ['E5', 'F5', 'G5', 'H5'],
#  '1:10.0_1': ['A6', 'B6', 'C6', 'D6'],
#  '1:10.0_2': ['E6', 'F6', 'G6', 'H6'],
#  '1:17.78_1': ['A7', 'B7', 'C7', 'D7'],
#  '1:17.78_2': ['E7', 'F7', 'G7', 'H7'],
#  '1:31.62_1': ['A8', 'B8', 'C8', 'D8'],
#  '1:31.62_2': ['E8', 'F8', 'G8', 'H8'],
#  '1:56.23_1': ['A9', 'B9', 'C9', 'D9'],
#  '1:56.23_2': ['E9', 'F9', 'G9', 'H9'],
#  '1:100.0_1': ['A10', 'B10', 'C10', 'D10'],
#  '1:100.0_2': ['E10', 'F10', 'G10', 'H10'],
#  '0:1_1': ['A11', 'B11', 'C11', 'D11'],
#  '0:1_2': ['E11', 'F11', 'G11', 'H11'],
#  'blank': ['B12', 'C12', 'D12', 'E12', 'F12']}

# %%
names = ['Time', 'T'] + ['{}{}'.format(x, y) for x in ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'] for y in np.arange(1, 13)]
df = pd.read_csv("../data/20240619_galactose_glucose_diauxie.txt", names=names).dropna()

def parse_time(x):
    arr = x.split(':')
    time = int(arr[1]) + 60 * int(arr[0]) + int(arr[2]) / 60
    return time
    
df['time [min]'] = df['Time'].apply(parse_time)
df.drop(columns=['Time', 'T'], inplace=True)

df = pd.melt(df, id_vars=['time [min]'], value_vars=df.columns[:-1], var_name='well', value_name='OD600')
df = df.loc[df['well'] != 'A12', :]
df = df.loc[df['well'] != 'G12', :]
df = df.loc[df['well'] != 'H12', :]
df['replicate'] = df['well'].apply(lambda x: well_metadata[x].split('_')[1] if well_metadata[x]!= 'blank' else 1)
df['cond'] = df['well'].apply(lambda x: well_metadata[x].split('_')[0])
df.head(5)
# Out:
#    time [min] well  OD600 replicate cond
# 0    6.166667   A1  0.088         1  1:0
# 1   13.166667   A1  0.088         1  1:0
# 2   20.166667   A1  0.088         1  1:0
# 3   27.166667   A1  0.088         1  1:0
# 4   34.166667   A1  0.088         1  1:0

# %%
def parse_time(x):
    arr = x.split(':')
    time = int(arr[1]) + 60 * int(arr[0]) + int(arr[2]) / 60
    return time

# %%
df[[x in conditions['blank'] for x in df['well']]]
# Out:
#         time [min] well  OD600 replicate   cond
# 4347      6.166667  B12  0.083         1  blank
# 4348     13.166667  B12  0.083         1  blank
# 4349     20.166667  B12  0.083         1  blank
# 4350     27.166667  B12  0.083         1  blank
# 4351     34.166667  B12  0.083         1  blank
# ...            ...  ...    ...       ...    ...
# 13603  1294.166667  F12  0.085         1  blank
# 13604  1301.166667  F12  0.084         1  blank
# 13605  1308.166667  F12  0.084         1  blank
# 13606  1315.166667  F12  0.085         1  blank
# 13607  1322.166667  F12  0.084         1  blank
#
# [945 rows x 5 columns]

# %%
df_blanks = df[[x in conditions['blank'] for x in df['well']]].groupby('time [min]')['OD600'].mean().reset_index()
df_blanks
# Out:
#       time [min]   OD600
# 0       6.166667  0.0846
# 1      13.166667  0.0846
# 2      20.166667  0.0846
# 3      27.166667  0.0848
# 4      34.166667  0.0846
# ..           ...     ...
# 184  1294.166667  0.0848
# 185  1301.166667  0.0846
# 186  1308.166667  0.0846
# 187  1315.166667  0.0846
# 188  1322.166667  0.0844
#
# [189 rows x 2 columns]

# %%
# Background traces
p = bokeh.plotting.figure(
    frame_width=400,
    frame_height=200,
    x_axis_label='time [min]',
    y_axis_label='absorbance',
)

# Plot all background traces
for well in conditions['blank']:
    p.line(x=df.loc[df['well'] == well, 'time [min]'], y=df.loc[df['well'] == well, 'OD600'])

# Overlay average blank
p.line(x=df_blanks['time [min]'], y=df_blanks['OD600'], color='tomato', line_width=2)

bokeh.io.show(p)
# Out:
#   <div id="ad2f18dc-7390-4491-8d0c-889e2c0c8de9" data-root-id="p3753" style="display: contents;"></div>

# %%
df

# Instantiate figure
p = bokeh.plotting.figure(
    frame_width=400,
    frame_height=200,
    x_axis_label='time [min]',
    y_axis_label='absorbance',
)

# %%
sub_df['OD600']
# Out:
# 6804    0.088
# 6805    0.088
# 6806    0.088
# 6807    0.088
# 6808    0.088
#         ...
# 6988    1.662
# 6989    1.660
# 6990    1.659
# 6991    1.657
# 6992    1.656
# Name: OD600, Length: 189, dtype: float64

# %%
# Instantiate figure
p = bokeh.plotting.figure(
    frame_width=400,
    frame_height=200,
    x_axis_label='time [min]',
    y_axis_label='absorbance',
)

df_mean = df.groupby(['time [min]', 'replicate', 'cond'])['OD600'].mean().reset_index()

# Loop through and add a line for each pure glucose trace
for well in conditions['1:0_1']:
    sub_df = df.loc[df['well'] == well, :]
    p.line(x=sub_df['time [min]'], y=sub_df['OD600'].values - df_blanks['OD600'].values)
 


for well in conditions['1:0_2']:
    sub_df = df.loc[df['well'] == well, :]
    p.line(x=sub_df['time [min]'], y=sub_df['OD600'].values - df_blanks['OD600'].values)
    
for well in conditions['0:1_1']:
    sub_df = df.loc[df['well'] == well, :]
    p.line(x=sub_df['time [min]'], y=sub_df['OD600'].values - df_blanks['OD600'].values)

for well in conditions['0:1_2']:
    sub_df = df.loc[df['well'] == well, :]
    p.line(x=sub_df['time [min]'], y=sub_df['OD600'].values - df_blanks['OD600'].values)

sub_df_mean = df_mean.loc[(df_mean['cond'] == "1:0") & (df_mean['replicate'] == '1'), :]   
p.line(x=sub_df_mean['time [min]'], y=sub_df_mean['OD600'].values - df_blanks['OD600'].values, color="orange")

sub_df_mean = df_mean.loc[(df_mean['cond'] == "1:0") & (df_mean['replicate'] == '2'), :]   
p.line(x=sub_df_mean['time [min]'], y=sub_df_mean['OD600'].values - df_blanks['OD600'].values, color="orange")

sub_df_mean = df_mean.loc[(df_mean['cond'] == "0:1") & (df_mean['replicate'] == '1'), :]   
p.line(x=sub_df_mean['time [min]'], y=sub_df_mean['OD600'].values - df_blanks['OD600'].values, color="orange")

sub_df_mean = df_mean.loc[(df_mean['cond'] == "0:1") & (df_mean['replicate'] == '2'), :]   
p.line(x=sub_df_mean['time [min]'], y=sub_df_mean['OD600'].values - df_blanks['OD600'].values, color="orange")

bokeh.io.show(p)
# Out:
#   <div id="f4102386-1dc7-4c14-b73a-49eafb62018c" data-root-id="p5537" style="display: contents;"></div>

# %%
# Instantiate figure
p = bokeh.plotting.figure(
    frame_width=800,
    frame_height=400,
    x_axis_label='time [min]',
    y_axis_label='absorbance',
    y_axis_type="log"
)

df_mean = df.groupby(['time [min]', 'replicate', 'cond'])['OD600'].mean().reset_index()
df_mean = df_mean.loc[df_mean['cond'] != 'blank', :]
# Loop through and add a line for each pure glucose trace
for cond in ['1:0', '0:1', '1:31.62', '1:10.0', '1:100.0']:
    for rep in ['1', '2']:
        for well in conditions[cond+'_'+rep]:
            sub_df = df.loc[df['well'] == well, :]
            p.line(x=sub_df['time [min]'], y=sub_df['OD600'].values - df_blanks['OD600'].values)

for cond in ['1:0', '0:1', '1:31.62', '1:100.0']:
    for rep in ['1', '2']:
        sub_df_mean = df_mean.loc[(df_mean['cond'] == cond) & (df_mean['replicate'] ==rep), :]   
        p.line(x=sub_df_mean['time [min]'], y=sub_df_mean['OD600'].values - df_blanks['OD600'].values, color="orange", line_width=1.5)


bokeh.io.show(p)
# Out:
#   <div id="c8fed03b-c909-409d-bb67-d08ba94eb1eb" data-root-id="p10580" style="display: contents;"></div>

# %%
# Instantiate figure
p = bokeh.plotting.figure(
    frame_width=800,
    frame_height=400,
    x_axis_label='time [min]',
    y_axis_label='absorbance',
    y_axis_type="log"
)

df_mean = df.groupby(['time [min]', 'replicate', 'cond'])['OD600'].mean().reset_index()
df_mean = df_mean.loc[df_mean['cond'] != 'blank', :]
# Loop through and add a line for each pure glucose trace

# Items we will place in the legend
legend_items = []
for cond, color in zip(df_mean['cond'].unique(), bokeh.palettes.Category20_20):
    lines = []
    for rep in ['1', '2']:
        sub_df_mean = df_mean.loc[(df_mean['cond'] == cond) & (df_mean['replicate'] ==rep), :]   
        line = p.line(x=sub_df_mean['time [min]'], y=sub_df_mean['OD600'].values - df_blanks['OD600'].values, line_width=1.5, color=color)
        lines.append(line)
    legend_items.append((cond, lines))


# Create the legend from the items
legend = bokeh.models.Legend(items=legend_items, click_policy="hide")

# Add the legend to the plot
p.add_layout(legend, "right")

bokeh.io.show(p)
# Out:
#   <div id="e4f2ebc1-a4db-47b7-8727-fc055886a05a" data-root-id="p12548" style="display: contents;"></div>

# %%
df_merge = pd.merge(df_mean, df_blanks, on="time [min]")
df_merge['OD600'] = df_merge['OD600_x'] - df_merge['OD600_y']
df_merge.drop(columns=['OD600_x', 'OD600_y'], inplace=True)
df_merge
# Out:
#        time [min] replicate     cond    OD600
# 0        6.166667         1      0:1  0.00390
# 1        6.166667         1      1:0  0.00390
# 2        6.166667         1      1:1  0.00315
# 3        6.166667         1   1:1.78  0.00290
# 4        6.166667         1   1:10.0  0.00640
# ...           ...       ...      ...      ...
# 4153  1322.166667         2  1:17.78  1.54760
# 4154  1322.166667         2   1:3.16  1.56510
# 4155  1322.166667         2  1:31.62  1.54735
# 4156  1322.166667         2   1:5.62  1.56410
# 4157  1322.166667         2  1:56.23  1.56210
#
# [4158 rows x 4 columns]

# %%
# Define exponential growth function
def exp_growth(t, A0, r):
    return A0 * np.exp(r * t)

def fit_growth(t, A):
    """Obtain estimates for A0 and r for a given sub-trace"""
    # Parameter guesses
    A0_guess = 0.01
    r_guess = 1/60  # 1/hr

    # Pull out data


    # Perform optimization
    popt, _ = scipy.optimize.curve_fit(exp_growth, t, A, p0=(A0_guess, r_guess))

    return popt

times = {   
    "1:0": [200, 500],
    "0:1": [400, 800],
    "1:100.0": [400, 600],
    "1:31.62": [400, 600],
    "1:56.23": [400, 600],
    "1:17.78": [500, 600],
    "1:10.0": [500, 600],
    "1:5.62": [530, 610],
}
results = []
for cond in list(times.keys()):
    for rep in ['1', '2']:
        t_start, t_end = times[cond]
        sub_df = df_merge.loc[(df_merge["time [min]"] >= t_start) & \
                              (df_merge["time [min]"] <= t_end) & \
                              (df_merge['cond'] == cond) & \
                              (df_merge['replicate'] == rep), :]
        
        t = sub_df["time [min]"].values
        A = sub_df["OD600"].values
        A0, r = fit_growth(t, A)
        results.append(dict(cond=cond, replicate=rep, A0=A0, r=r))

# Make a data frame from the list of results
df_growth_rates = pd.DataFrame(results)

# Take a look
df_growth_rates
# Out:
#        cond replicate        A0         r
# 0       1:0         1  0.001698  0.010906
# 1       1:0         2  0.001775  0.010748
# 2       0:1         1  0.006212  0.004649
# 3       0:1         2  0.007744  0.004483
# 4   1:100.0         1  0.007565  0.006292
# 5   1:100.0         2  0.007273  0.006413
# 6   1:31.62         1  0.007366  0.007164
# 7   1:31.62         2  0.006368  0.007367
# 8   1:56.23         1  0.008534  0.006517
# 9   1:56.23         2  0.007190  0.006846
# 10  1:17.78         1  0.008211  0.007324
# 11  1:17.78         2  0.007831  0.007382
# 12   1:10.0         1  0.008890  0.007478
# 13   1:10.0         2  0.008691  0.007505
# 14   1:5.62         1  0.016345  0.006573
# 15   1:5.62         2  0.015175  0.006690

# %%
order = (
    ("1:0", '1'),
    ("1:0", '2'),
    ("1:5.62", '1'),
    ("1:5.62", '2'),
    ("1:10.0", '1'),
    ("1:10.0", '2'),
    ("1:17.78", '1'),
    ("1:17.78", '2'),
    ("1:31.62", '1'),
    ("1:31.62", '2'),
    ("1:56.23", '1'),
    ("1:56.23", '2'),
    ("1:100.0", '1'),
    ("1:100.0", '2'),
    ("0:1", '1'),
    ("0:1", '2'),
)

# Colors
colors = ['#1f77b4', 'orange'] * 8


p = iqplot.strip(
    df_growth_rates,
    q="r",
    cats=['cond', 'replicate'],
    q_axis='y',
    y_axis_label="growth rate (1/min)",
    spread="swarm",
    frame_width=500,
    frame_height=300,
    order=order,
    palette=colors,
    x_axis_label="Glucose:Galactose"
)

bokeh.io.show(p)
# Out:
#   <div id="c0d88881-d26a-4ed1-8289-f3ff580d7f4c" data-root-id="p13121" style="display: contents;"></div>

# %%
np.random.rand(10) > 1
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False])

# %%
df_mean = df.groupby(['time [min]', 'replicate', 'cond'])['OD600'].mean().reset_index()
df_mean
# Out:
#        time [min] replicate     cond    OD600
# 0        6.166667         1    blank  0.08460
# 1        6.166667         1      0:1  0.08850
# 2        6.166667         1      1:0  0.08850
# 3        6.166667         1      1:1  0.08775
# 4        6.166667         1   1:1.78  0.08750
# ...           ...       ...      ...      ...
# 4342  1322.166667         2  1:17.78  1.63200
# 4343  1322.166667         2   1:3.16  1.64950
# 4344  1322.166667         2  1:31.62  1.63175
# 4345  1322.166667         2   1:5.62  1.64850
# 4346  1322.166667         2  1:56.23  1.64650
#
# [4347 rows x 4 columns]

# %%
1.0
1.77827941003892
3.16227766016838
5.62341325190349
10.0
17.7827941003892
31.6227766016838
56.2341325190349
100.0

# %%
# Instantiate figure
p = bokeh.plotting.figure(
    frame_width=700,
    frame_height=400,
    x_axis_label='time [min]',
    y_axis_label='absorbance',
    y_axis_type='log',
    x_range=[0, 1200],
)

# Loop through and add a line for each pure glucose trace
legend_items = []
# Loop through conditions with pretty colors
for condition, color in zip(["1:0_1", "1:1_1", '1:1.78_1', '1:3.16_1', '1:5.62_1', '1:10.0_1', '1:17.78_1', '1:31.62_1', '1:56.23_1', '1:100.0_1', '0:1_1'], colorcet.b_glasbey_category10):
    line = p.line(x=df['time [min]'], y=df[conditions[condition]].mean(axis=1) - df['background'], color=color)
    legend_items.append((condition, [line]))



# Create the legend from the items
legend = bokeh.models.Legend(items=legend_items, click_policy="hide")

# Add the legend to the plot
p.add_layout(legend, "right")

bokeh.io.show(p)
# Out:
#   <div id="e3231698-d5dd-4528-a4f6-423a39faafd4" data-root-id="p2736" style="display: contents;"></div>
